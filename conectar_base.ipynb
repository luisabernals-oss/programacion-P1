# %% [markdown]
# <a href="https://colab.research.google.com/github/luisabernals-oss/programacion-P1/blob/main/conectar_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymysql pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import pymysql
import pandas as pd

connection = pymysql.connect(
    host="relational.fel.cvut.cz",
    port=3306,
    user="guest",
    password="ctu-relational",
    database="restbase"
)

print("Conectado!")
# Out:
# Conectado!

# %%
query = "SHOW TABLES"
tables = pd.read_sql(query, connection)
tables
# Out:
# /tmp/ipykernel_6711/1992093721.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, connection)
#   Tables_in_restbase
# 0        generalinfo
# 1         geographic
# 2           location

# %%
query = "SELECT * FROM location"
df = pd.read_sql(query, connection)

df.to_csv("tabla.csv", index=False)
df.head()
# Out:
# /tmp/ipykernel_6711/1140612496.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#    id_restaurant  street_num        street_name           city
# 0              1       242.0          church st  san francisco
# 1              2       135.0     el camino real     san carlos
# 2              3       430.0           broadway  san francisco
# 3              4      1103.0  e. el camino real      sunnyvale
# 4              5       833.0  w. el camino real      sunnyvale

# %% [markdown]
# ## variables

# %%
query = "SHOW TABLES"
tables = pd.read_sql(query, connection)

tables
# Out:
# /tmp/ipykernel_6711/3893829325.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, connection)
#   Tables_in_restbase
# 0        generalinfo
# 1         geographic
# 2           location

# %%
table_list = tables.iloc[:,0].tolist()
table_list
# Out:
# ['generalinfo', 'geographic', 'location']

# %%
for table in table_list:
    print("\nTabla:", table)

    query = f"DESCRIBE {table}"
    df = pd.read_sql(query, connection)

    display(df)
# Out:
# /tmp/ipykernel_6711/1202941598.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
# Tabla: generalinfo
#            Field          Type Null  Key Default Extra
# 0  id_restaurant       int(11)   NO  PRI    None
# 1          label  varchar(255)  YES         None
# 2      food_type  varchar(255)  YES         None
# 3           city  varchar(255)  YES  MUL    None
# 4         review  decimal(2,1)  YES         None
# Tabla: geographic
# /tmp/ipykernel_6711/1202941598.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#     Field          Type Null  Key Default Extra
# ...

# %% [markdown]
# ## ver datos

# %%
query = "SELECT * FROM generalinfo LIMIT 10"
df = pd.read_sql(query, connection)

df
# Out:
# /tmp/ipykernel_6711/3467504048.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#    id_restaurant                     label      food_type           city  \
# 0              1            sparky's diner  24 hour diner  san francisco
# 1              2      kabul afghan cuisine        afghani     san carlos
# 2              3        helmand restaurant        afghani  san francisco
# 3              4             afghani house        afghani      sunnyvale
# 4              5       kabul afghan cusine        afghani      sunnyvale
# 5              6  bamyan afghan restaurant        afghani     san rafael
# 6              7              kabul palace        afghani       san jose
# 7              8                  kandahar        afghani        concord
# ...

# %%
tables = ["generalinfo", "geographic", "location"]

for table in tables:
    print("\nDatos de la tabla:", table)

    query = f"SELECT * FROM {table} LIMIT 5"
    df = pd.read_sql(query, connection)

    display(df)
# Out:
# /tmp/ipykernel_6711/33771661.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
# Datos de la tabla: generalinfo
#    id_restaurant                 label      food_type           city  review
# 0              1        sparky's diner  24 hour diner  san francisco     2.3
# 1              2  kabul afghan cuisine        afghani     san carlos     3.8
# 2              3    helmand restaurant        afghani  san francisco     4.0
# 3              4         afghani house        afghani      sunnyvale     3.6
# 4              5   kabul afghan cusine        afghani      sunnyvale     3.7
# Datos de la tabla: geographic
# ...

# %%
generalinfo = pd.read_sql("SELECT * FROM generalinfo", connection)
geographic = pd.read_sql("SELECT * FROM geographic", connection)
location = pd.read_sql("SELECT * FROM location", connection)
# Out:
# /tmp/ipykernel_6711/2843710696.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   generalinfo = pd.read_sql("SELECT * FROM generalinfo", connection)
# /tmp/ipykernel_6711/2843710696.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   geographic = pd.read_sql("SELECT * FROM geographic", connection)
# /tmp/ipykernel_6711/2843710696.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   location = pd.read_sql("SELECT * FROM location", connection)

# %%
generalinfo.head()
geographic.head()
location.head()
# Out:
#    id_restaurant  street_num        street_name           city
# 0              1       242.0          church st  san francisco
# 1              2       135.0     el camino real     san carlos
# 2              3       430.0           broadway  san francisco
# 3              4      1103.0  e. el camino real      sunnyvale
# 4              5       833.0  w. el camino real      sunnyvale

# %%
## join




import pandas as pd

generalinfo = pd.read_sql("SELECT * FROM generalinfo", connection)
geographic = pd.read_sql("SELECT * FROM geographic", connection)
location = pd.read_sql("SELECT * FROM location", connection)
# Out:
# /tmp/ipykernel_6711/1878947171.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   generalinfo = pd.read_sql("SELECT * FROM generalinfo", connection)
# /tmp/ipykernel_6711/1878947171.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   geographic = pd.read_sql("SELECT * FROM geographic", connection)
# /tmp/ipykernel_6711/1878947171.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   location = pd.read_sql("SELECT * FROM location", connection)

# %%
data = generalinfo.merge(geographic, on="placeID") \
                  .merge(location, on="placeID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6711/361089831.py in <cell line: 0>()
# ----> 1 data = generalinfo.merge(geographic, on="placeID") \
#       2                   .merge(location, on="placeID")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
# ...

# %%
query = """
SELECT *
FROM consumer c
JOIN rating r ON c.consumer_id = r.consumer_id
JOIN restaurant t ON r.restaurant_id = t.restaurant_id
LIMIT 100
"""

df = pd.read_sql(query, connection)
# Out:
# /tmp/ipykernel_6711/1518767378.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# /usr/local/lib/python3.12/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     152
# --> 153         result = self._query(query)
#     154         self._executed = query
#
# /usr/local/lib/python3.12/dist-packages/pymysql/cursors.py in _query(self, q)
#     321         self._clear_result()
# --> 322         conn.query(q)
# ...
